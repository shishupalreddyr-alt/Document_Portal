# %%
### __file__ in .py file automatically gets the name of the file

# %% [markdown]
# ### Exception handling

# %%
import sys
import traceback  ## capture detailed execution 
import logger

# %%
class DocumentPortalException(Exception):
    """Custom exception for Document Portal"""
    def __init__(self,error_message:str,error_details:sys):
        print(error_details.exc_info())
        _,_,exc_tb=error_details.exc_info()
        #Filename
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        #Line number 
        self.lineno=exc_tb.tb_lineno
        #Error message 
        self.error_message=str(error_message)
        #Error details formated 
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info())) 
    def __str__(self):
       return f"""
        Error in [{self.file_name}] at line [{self.lineno}]
        Message: {self.error_message}
        Traceback:
        {self.traceback_str}
        """
    
if __name__ == "__main__":
    try:
    # Simulate an error
        a = 1 / 0
        print(a)
    except Exception as e:

        app_exc=DocumentPortalException(e,sys) # type: ignore
        logger.error("An index error occurred: %s", app_exc)
        #logger.error("An error occurred in the Document Portal application.")

        raise app_exc
# Out:
# (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x0000018883FB9D80>)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[32], line 25
#      23 try:
#      24 # Simulate an error
# ---> 25     a = 1 / 0
#      26     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 30
#      27 except Exception as e:
#      29     app_exc=DocumentPortalException(e,sys) # type: ignore
# ---> 30     logger.error(app_exc) # type: ignore
#      31     #logger.error("An error occurred in the Document Portal application.")
#      33     raise app_exc
#
# TypeError: error() missing 1 required positional argument: 'msg'

# %% [markdown]
# ### Lets handle Exceptions in an LLM based Generative AI project
# # Log the exceptions in console, Custom file,or cloud config files
# # Raise the exceptions
