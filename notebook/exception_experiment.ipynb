# %%
### __file__ in .py file automatically gets the name of the file

# %%
import structlog

# %% [markdown]
# ### Lets handle Exceptions in an LLM based Generative AI project

# %%
from logger.custom_logger import CustomLogger

logger = CustomLogger().get_logger(__file__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from logger.custom_logger import CustomLogger
#       3 logger = CustomLogger().get_logger(__file__)
#
# ImportError: cannot import name 'CustomLogger' from 'logger.custom_logger' (C:\LLMOpSProjects\Document_Portal\logger\custom_logger.py)

# %%
logger=CustomLogger().get_logger("exceptions experiment")
